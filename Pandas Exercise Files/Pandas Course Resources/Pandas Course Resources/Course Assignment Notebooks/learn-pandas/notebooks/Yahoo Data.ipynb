# %% [markdown]
# <!-- ---------------------------------------------------- -->
#   <div class="col-sm-3 col-md-3 col-lg-3">
# 	<!-- logo -->
#     <div class="img-responsive">
#       <img src="https://www.dropbox.com/s/220ncn0o5danuey/pandas-ipython-tutorials-hedaro.jpg?dl=1" title="Pandas Tutorial | Hedaro" alt="Pandas Tutorial | Hedaro">
#     </div>
# 	<!-- logo -->
#   </div>
# <!-- ---------------------------------------------------- -->
#   <div class="col-sm-6 col-md-6 col-lg-6">
# 	<!-- Pandas Tutorial -->
# 	  <center>
# 	    <br>
#         <h1>Some code you can use to pull stock data from Yahoo</h1>
# 	  </center>
#     <!-- Pandas Tutorial -->
#   </div>
# <!-- ---------------------------------------------------- -->

# %% [markdown]
# <strong>The most popular Pandas tutorials. </strong><a href="https://gumroad.com/l/jVeRh" target="_blank"><strong>Get a total of 7 tutorials!</strong></a>

# %%
import pandas as pd
import yfinance as yf
# %matplotlib inline

# %% [markdown]
# The library ***pandas_datareader*** was my go to for pulling stock data from Yahoo. As of April 2024, I have had no luck getting it to work, so this is why I am now using yfinance.
#
# ```python
# pip install yfinance
# ```

# %%
# Pick your favorite stock!
ticker_symbol = 'AAPL'

# Select some dates to play with
start = '2023-01-01'
end = '2023-08-02'

# get data
df = stock_data = yf.download(ticker_symbol, start, end)

df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  130.279999  130.899994  124.169998  125.070000  124.216301
# 2023-01-04  126.889999  128.660004  125.080002  126.360001  125.497505
# 2023-01-05  127.129997  127.769997  124.760002  125.019997  124.166641
# 2023-01-06  126.010002  130.289993  124.889999  129.619995  128.735229
# 2023-01-09  130.470001  133.410004  129.889999  130.149994  129.261627
# ...                ...         ...         ...         ...         ...
# 2023-07-26  193.669998  195.639999  193.320007  194.500000  193.734940
# 2023-07-27  196.020004  197.199997  192.550003  193.220001  192.459976
# 2023-07-28  194.669998  196.630005  194.139999  195.830002  195.059708
# 2023-07-31  196.059998  196.490005  195.259995  196.449997  195.677261
# 2023-08-01  196.240005  196.729996  195.279999  195.610001  194.840561
#
#                Volume
# Date
# 2023-01-03  112117500
# 2023-01-04   89113600
# 2023-01-05   80962700
# 2023-01-06   87754700
# 2023-01-09   70790800
# ...               ...
# 2023-07-26   47471900
# 2023-07-27   47460200
# 2023-07-28   48291400
# 2023-07-31   38824100
# 2023-08-01   35175100
#
# [145 rows x 6 columns]

# %% [markdown]
# > Explore the dataframe using the ***info()*** function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145 entries, 2023-01-03 to 2023-08-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       145 non-null    float64
#  1   High       145 non-null    float64
#  2   Low        145 non-null    float64
#  3   Close      145 non-null    float64
#  4   Adj Close  145 non-null    float64
#  5   Volume     145 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# ## Open vs. Close Prices

# %%
df[['Open', 'Close']].plot(figsize=(15,5));

# %% [markdown]
# ## You can also slice your data by a date range

# %%
df.loc['2023-01-12':'2023-02-05', ['Open', 'Close']].plot(figsize=(15,5));

# %% [markdown]
# ## Get the median percentage change of Closing prices... say what?

# %%
df.Close.pct_change().median()
# Out:
# 0.0020191845386791085

# %% [markdown]
# ## Chart the Percentage change of Closing prices

# %%
df.Close.pct_change().plot(figsize=(15,5));

# %% [markdown]
# ## You can also slice by Month

# %%
df.loc['2023-02']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-02-01  143.970001  146.610001  141.320007  145.429993  144.437317
# 2023-02-02  148.899994  151.179993  148.169998  150.820007  149.790543
# 2023-02-03  148.029999  157.380005  147.830002  154.500000  153.445419
# 2023-02-06  152.570007  153.100006  150.779999  151.729996  150.694321
# 2023-02-07  150.639999  155.229996  150.639999  154.649994  153.594406
# 2023-02-08  153.880005  154.580002  151.169998  151.919998  150.883011
# 2023-02-09  153.779999  154.330002  150.419998  150.869995  149.840195
# 2023-02-10  149.460007  151.339996  149.220001  151.009995  150.208221
# 2023-02-13  150.949997  154.259995  150.919998  153.850006  153.033157
# 2023-02-14  152.119995  153.770004  150.860001  153.199997  152.386597
# 2023-02-15  153.110001  155.500000  152.880005  155.330002  154.505295
# 2023-02-16  153.509995  156.330002  153.350006  153.710007  152.893890
# 2023-02-17  152.350006  153.000000  150.850006  152.550003  151.740067
# 2023-02-21  150.199997  151.300003  148.410004  148.479996  147.691650
# 2023-02-22  148.869995  149.949997  147.160004  148.910004  148.119385
# 2023-02-23  150.089996  150.339996  147.240005  149.399994  148.606781
# 2023-02-24  147.110001  147.190002  145.720001  146.710007  145.931076
# 2023-02-27  147.710007  149.169998  147.449997  147.919998  147.134628
# 2023-02-28  147.050003  149.080002  146.830002  147.410004  146.627350
#
#                Volume
# Date
# 2023-02-01   77663600
# 2023-02-02  118339000
# 2023-02-03  154357300
# 2023-02-06   69858300
# 2023-02-07   83322600
# 2023-02-08   64120100
# 2023-02-09   56007100
# 2023-02-10   57450700
# 2023-02-13   62199000
# 2023-02-14   61707600
# 2023-02-15   65573800
# 2023-02-16   68167900
# 2023-02-17   59144100
# 2023-02-21   58867200
# 2023-02-22   51011300
# 2023-02-23   48394200
# 2023-02-24   55469600
# 2023-02-27   44998500
# 2023-02-28   50547000

# %% [markdown]
# <p class="text-muted">This tutorial was created by <a href="http://www.hedaro.com" target="_blank"><strong>HEDARO</strong></a></p>
