# %%
colors = ['red', 'blue', 'green', 'black', 'white']
colors.append('pink')
colors
# Out:
# ['red', 'blue', 'green', 'black', 'white', 'pink']

# %%
colors.pop() # removes and returns the last item
# Out:
# 'pink'

# %%
colors.extend(['pink', 'purple']) # extend colors, in-place
colors
# Out:
# ['red', 'blue', 'green', 'black', 'white', 'pink', 'purple']

# %%
colors = colors[:-2]
colors
# Out:
# ['red', 'blue', 'green', 'black', 'white']

# %%
rcolors = colors[::-1]
rcolors
# Out:
# ['white', 'black', 'green', 'blue', 'red']

# %%
rcolors2 = list(colors) # new object that is a copy of colors in a different memory area
rcolors2
# Out:
# ['red', 'blue', 'green', 'black', 'white']

# %%
rcolors2.reverse() # in-place; reversing rcolors2 does not affect colors
rcolors2
# Out:
# ['white', 'black', 'green', 'blue', 'red']

# %%
rcolors + colors
# Out:
# ['white',
#  'black',
#  'green',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'green',
#  'black',
#  'white']

# %%
rcolors * 2
# Out:
# ['white',
#  'black',
#  'green',
#  'blue',
#  'red',
#  'white',
#  'black',
#  'green',
#  'blue',
#  'red']

# %%
sorted(rcolors) # new object
# Out:
# ['black', 'blue', 'green', 'red', 'white']

# %%
rcolors.sort()  # in-place
rcolors
# Out:
# ['black', 'blue', 'green', 'red', 'white']

# %%
rcolors.<TAB>


rcolors.<TAB>
                 append()  count()   insert()  reverse()
                 clear()   extend()  pop()     sort()
                 copy()    index()   remove()

# %%
s = 'Hello, how are you?'
s = "Hi, what's up"
s = '''Hello,
       how are you'''         # tripling the quotes allows the
                              # string to span more than one line
s = """Hi,
what's up?"""
s
# Out:
# "Hi,\nwhat's up?"

# %%
# Strings are collections like lists. Hence they can be indexed and sliced, using the same syntax and rules.
a = "hello"
print(a[0])
print(a[-1])
# Out:
# h
# o

# %%
a = "hello, world!"
a[3:6] # 3rd to 6th (excluded) elements: elements 3, 4, 5
# Out:
# 'lo,'

# %%
a[2:10:2] # Syntax: a[start:stop:step]
# Out:
# 'lo o'

# %%
a[::3] # every three characters, from beginning to end
# Out:
# 'hl r!'

# %%
# A string is an immutable object and it is not possible to modify its contents. One may however create new strings from the original one.
a = "hello, world!"
a[2] = 'z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # A string is an immutable object and it is not possible to modify its contents. One may however create new strings from the original one.
#       2 a = "hello, world!"
# ----> 3 a[2] = 'z'
#
# TypeError: 'str' object does not support item assignment

# %%
a.replace('l', 'z', 1)
# Out:
# 'hezlo, world!'

# %%
a.replace('l', 'z')
# Strings have many useful methods, such as a.replace as seen above. 
# Remember the a. object-oriented notation and use tab completion or help(str) to search for new methods.
# Out:
# 'hezzo, worzd!'

# %%
# String formatting:
'An integer: %i; a float: %f; another string: %s' % (1, 0.1, 'string') # with more values use tuple after %
# Out:
# 'An integer: 1; a float: 0.100000; another string: string'

# %%
i = 102
filename = 'processing_of_dataset_%d.txt' % i   # no need for tuples with just one value after %
filename
# Out:
# 'processing_of_dataset_102.txt'

# %% [markdown]
# Dictionaries

# %%
tel = {'emmanuelle': 5752, 'sebastian': 5578}
tel['francis'] = 5915
tel
# Out:
# {'emmanuelle': 5752, 'sebastian': 5578, 'francis': 5915}

# %%
tel['sebastian']
# Out:
# 5578

# %%
print(tel.keys())
print(tel.values())
print('francis' in tel)
d = {'a':1, 'b':2, 3:'hello'}
print(d)
# Out:
# dict_keys(['emmanuelle', 'sebastian', 'francis'])
# dict_values([5752, 5578, 5915])
# True
# {'a': 1, 'b': 2, 3: 'hello'}

# %% [markdown]
# More container types
# Tuples
#
# Tuples are basically immutable lists. The elements of a tuple are written between parentheses, or just separated by commas:

# %%
t = 12345, 54321, 'hello!'
print(t)
print(t[0])

u = (0, 2)
print(u)
# Out:
# (12345, 54321, 'hello!')
# 12345
# (0, 2)

# %%
# Sets: unordered, unique items:
s = set(('a', 'b', 'c', 'a'))
print(s)
print(s.difference(('a', 'b')))
# Out:
# {'a', 'b', 'c'}
# {'c'}

# %%
a = [1, 2, 3]
print(a)
a = ['a', 'b', 'c'] # Creates another object.
print(a)
print(id(a))
a[:] = [1, 2, 3] # Modifies object in place.
print(a)
print(id(a))
# Out:
# [1, 2, 3]
# ['a', 'b', 'c']
# 140451034044352
# [1, 2, 3]
# 140451034044352
